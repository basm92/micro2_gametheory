# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

import matplotlib

# %%
# Parameters
b = 1
a = 10
c = 1

root = 0

# %%
# maybe new attempt

def profit1(a1, a2):
    if a1 + a2 <= 100:
        profit = a1
    elif a1 + a2 > 100 and a1 < a2:
        profit = a1
    elif a1 + a2 > 100 and a1 > a2:
        profit = 100 - a2
    elif a1 + a2 > 100 and a1 == a2:
        profit = 50
    return profit

# %%
a1 = np.linspace(0, 100, num = 101)
a2 = 100
plt.plot([profit1(x, a2) for x in a1]) 

a2 = 99
plt.plot([profit1(x, a2) for x in a1]) 

a2 = 98
plt.plot([profit1(x, a2) for x in a1])

# %%
a2 = 50
plt.plot([profit1(x, a2) for x in a1]) 

a2 = 51
plt.plot([profit1(x, a2) for x in a1]) 

plt.savefig('plot_payoffs.png')

# %%
def plot_pi_1(q2, q3):
    root = (a - b*q2 - b*q3 - c)/b
    q1 = np.array(np.linspace(0.0, root, num=100))
    pi = -b * q1**2 + (a-c-b*(q2+q3))*q1
    return plt.plot(q1, pi)

# %%
plot_pi_1(2,2)
plot_pi_1(3,3)
plot_pi_1(4,4)

# %%
# player 1 plays maximum (a-c)/2b
# What does player 2 then do?
# q1 = (a-c)/2*b

def plot_pi_2(q1, q3):
    root = (a - b*q1 - b*q3 - c)/b
    q2 = np.array(np.linspace(0.0, root, num=100))
    pi = -b * q2**2 + (a-c-b*(q1+q3))*q2
    return plt.plot(q2, pi)

# %%
plot_pi_2((a-c)/(2*b), 0)
plot_pi_2((a-c)/(2*b), 2)

# %%
# Assignment 6

# %%
profit = 0

def profit_1(a1, a2):
    if a2 == 50:
        if a1 >= 50:
            profit = 50
        elif a1 < 50:
            profit = a1
    if a2 > 50:
        if a1 < 50:
            profit = a1
        elif a1 >= 50 and a1 > a2:
            profit = a2
        elif a1 >= 50 and a1 < a2:
            profit = a1
        elif a1 >= 50 and a1 == a2:
            profit = 50
    if a2 < 50:
        if a1 <= 50:
            profit = a1
        elif a1 > 50 and a1 + a2 <= 100:
            profit = a1
        elif a1 > 50 and a1 + a2 > 100:
            profit = a2
    return profit

# %%
a1 = np.linspace(0, 100, num = 101)

a2 = 60
plt.plot([profit_1(x, a2) for x in a1]) 

a2 = 70
plt.plot([profit_1(x, a2) for x in a1]) 

a2 = 100
plt.plot([profit_1(x, a2) for x in a1])

# %%
a2 = 40
plt.plot([profit_1(x, a2) for x in a1]) 

a2 = 30
plt.plot([profit_1(x, a2) for x in a1]) 

a2 = 0
plt.plot([profit_1(x, a2) for x in a1])

# %%
a2 = 50
plt.plot([profit_1(x, a2) for x in a1])

# %%
# maybe new attempt

def profit1(a1, a2):
    if a1 + a2 <= 100:
        profit = a1
    elif a1 + a2 > 100 and a1 < a2:
        profit = a1
    elif a1 + a2 > 100 and a1 > a2:
        profit = 100 - a2
    elif a1 + a2 > 100 and a1 == a2:
        profit = 50
    return profit
# Out:
# 30

# %%
#picture 1: a2 < 50

a2 = 10
plt.plot([profit1(x, a2) for x in a1]) 

a2 = 40
plt.plot([profit1(x, a2) for x in a1])

# %%
# http://www.rncarpio.com/teaching/CUR412/midterm_solutions.pdf
